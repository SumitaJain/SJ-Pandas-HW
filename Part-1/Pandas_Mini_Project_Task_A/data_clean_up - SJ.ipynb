# %% [markdown]
# **BIG BIG HINT! Look in the instructions to guide you on this task.**

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
df = pd.read_csv("Resources/2016-FCC-New-Coders-Survey-Data.csv", low_memory=False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Inspect all columns
df.count()
# Out:
# Age                      13613
# AttendedBootcamp         15380
# BootcampFinish             933
# BootcampFullJobAfter       635
# BootcampLoanYesNo          934
# BootcampMonthsAgo          631
# BootcampName               895
# BootcampPostSalary         330
# BootcampRecommend          937
# ChildrenNumber            2554
# CityPopulation           13630
# CodeEventBootcamp           42
# CodeEventCoffee           2077
# CodeEventConferences      2898
# CodeEventDjangoGirls        18
# CodeEventGameJam            22
# CodeEventGirlDev           558
# CodeEventHackathons       2422
# CodeEventMeetup            313
# CodeEventNodeSchool        480
# CodeEventNone             8900
# CodeEventOther             921
# CodeEventRailsBridge       255
# CodeEventRailsGirls         14
# CodeEventStartUpWknd       743
# CodeEventWomenCode         711
# CodeEventWorkshop           23
# CommuteTime               8339
# CountryCitizen           13654
# CountryLive              13610
# ...

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
columns = [0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]
# extract_df = df.iloc[columns]

# The hint above was not yielding the correct results
extract_df = df.iloc[:, columns]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# extract_df.AttendedBootcamp.replace(to_replace=[0.0 ,1.0], value=['no', 'yes'])
# extract_df['AttendedBootcamp'] = extract_df['AttendedBootcamp'].apply(lambda x: 0.0 if x=='no' else 1)

# the hints above were not yielding the right results.
extract_df=extract_df.replace({0.0: "No", 1.0:"Yes"})
extract_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey
respondents = len(extract_df)
respondents
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp = extract_df.loc[extract_df["AttendedBootcamp"]=="Yes"]
attended_bootcamp.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                 No                 NaN                No            NaN
# 97                 No             45000.0                No            NaN
# 130               Yes             75000.0               Yes              3
# 159                No                 NaN                No            NaN
# 188               Yes                 NaN                No            NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# ...

# %%
# Calculate average age of attendees
average_age = extract_df["Age"].mean()

# Calculate how many people attended a bootcamp
attendee_count = attended_bootcamp["AttendedBootcamp"].count()

# Calculate how many attendees hold degrees
degree_count = school_degrees = attended_bootcamp["SchoolDegree"].count()

# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
gender_all = attended_bootcamp["Gender"].count()
male = attended_bootcamp["Gender"].value_counts()["male"]
female = attended_bootcamp["Gender"].value_counts()["female"]
non_binary = gender_all - male - female

# Calculate percentage of respondents who attended a bootcamp
attendee_percent = attendee_count / respondents * 100

# Calculate percentage of respondents belonging to each gender
# # I think these should be divided by attendee_count instead but the instructions (Comment above) asks for percent of respondents
male_percent = male / respondents * 100 
female_percent = female / respondents * 100
non_binary_percent = non_binary / respondents * 100

# Calculate percentage of attendees with a school degree
percent_degrees = degree_count / attendee_count * 100

# Calculate average post-bootcamp salary
average_post_salary = attended_bootcamp["BootcampPostSalary"].mean()

# %%
# Create a new table consolodating above calculations
summary = [{"# Survey Respondents": respondents, "Average Age": average_age, "# Bootcamp Attendees": attendee_count, 
            "% Bootcamp Attendees": attendee_percent, "# Degrees": degree_count, "% Degrees": percent_degrees, 
            "# Male": male, "# Female": female, "# Non-Binary": non_binary, "% Male": male_percent, 
            "% Female": female_percent, "% Non-Binary": non_binary_percent, "Average Post-Bootcamp Salary in $": average_post_salary}]
summary_df = pd.DataFrame(summary)
summary_df = summary_df[["# Survey Respondents", "# Bootcamp Attendees", "% Bootcamp Attendees", "# Degrees", "% Degrees", "# Male", "# Female", "# Non-Binary", "% Male", "% Female", "% Non-Binary", "Average Post-Bootcamp Salary in $"]]
summary_df
# Out:
#    # Survey Respondents  # Bootcamp Attendees  % Bootcamp Attendees  \
# 0                 15620                   953              6.101152
#
#    # Degrees  % Degrees  # Male  # Female  # Non-Binary    % Male  % Female  \
# 0        832  87.303253     496       326            11  3.175416  2.087068
#
#    % Non-Binary  Average Post-Bootcamp Salary in $
# 0      0.070423                       63740.506061

# %%
# Improve formatting before outputting spreadsheet
final_output = summary_df.round(2)
final_output
# Out:
#    # Survey Respondents  # Bootcamp Attendees  % Bootcamp Attendees  \
# 0                 15620                   953                   6.1
#
#    # Degrees  % Degrees  # Male  # Female  # Non-Binary  % Male  % Female  \
# 0        832       87.3     496       326            11    3.18      2.09
#
#    % Non-Binary  Average Post-Bootcamp Salary in $
# 0          0.07                           63740.51

# %%
# Export to Excel
final_output.to_excel('output/pandas_mini_project_A_output.xlsx', index=False)
